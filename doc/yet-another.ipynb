# %% [markdown]
# This notebook is part of the `nbsphinx` documentation: http://nbsphinx.readthedocs.org/.

# %% [markdown]
# # Yet Another Notebook
#
# This notebook is only here to show how (sub-)toctrees can be created with Markdown cell metadata.
# See [there](subdir/toctree.ipynb).
